# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv(r"D:\lnb data science course\pandas\IMDB-Movie-Data.csv")

# %%
x=[1,2,3,4,5]
y=[1,4,9,16,25]

# %%
x2=[3,4,5,6,7]
y2=[1,2,1,4,3]

# %%
fig=plt.figure()

# %%
plt.xlabel("marks")
plt.ylabel("hours")
plt.plot(x,y)
plt.scatter(x2,y2)
# plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.groupby(['Actors'])['Year']
