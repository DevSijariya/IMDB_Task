# %%
# 1. How do you load the IMDb dataset into a pandas DataFrame.
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv(r"D:\lnb data science course\pandas\IMDB-Movie-Data.csv")

# %%
print(data)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 2    Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4    A secret government agency recruits some of th...            David Ayer
# ..                                                 ...                   ...
# 995  A tight-knit team of rising investigators, alo...             Billy Ray
# 996  Three American college students studying abroa...              Eli Roth
# 997  Romantic sparks occur between two dance studen...            Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...        Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...      Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
# ..                                                 ...   ...
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# 996  Lauren German, Heather Matarazzo, Bijou Philli...  2007
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 0                  121     8.1  757074              333.13       76.0
# 1                  124     7.0  485820              126.46       65.0
# 2                  117     7.3  157606              138.12       62.0
# 3                  108     7.2   60545              270.32       59.0
# 4                  123     6.2  393727              325.02       40.0
# ..                 ...     ...     ...                 ...        ...
# 995                111     6.2   27585                 NaN       45.0
# 996                 94     5.5   73152               17.54       46.0
# 997                 98     6.2   70699               58.01       50.0
# 998                 93     5.6    4881                 NaN       22.0
# 999                 87     5.3   12435               19.64       11.0
#
# [1000 rows x 12 columns]

# %%
# 2. Display the first 5 rows of the dataset. What information can you gather from these rows?
data.iloc[0:5]
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0
# 2     7.3  157606              138.12       62.0
# 3     7.2   60545              270.32       59.0
# 4     6.2  393727              325.02       40.0

# %%
# 3. What method would you use to get an overview of column data types and missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
# 4. Identify the columns with missing values. What strategies can you use to handle them?
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
# 5. Which columns are essential for analyzing movie ratings and details? How would you drop the rest?
data.loc[:,['Rating','Votes']]
# Out:
#      Rating   Votes
# 0       8.1  757074
# 1       7.0  485820
# 2       7.3  157606
# 3       7.2   60545
# 4       6.2  393727
# ..      ...     ...
# 995     6.2   27585
# 996     5.5   73152
# 997     6.2   70699
# 998     5.6    4881
# 999     5.3   12435
#
# [1000 rows x 2 columns]

# %%
# 6. Calculate the average runtime of movies in the dataset.
data['Runtime (Minutes)'].mean()
# Out:
# 113.172

# %%
# 7. Count the number of movies in each genre. How can you present this information visually?
data.value_counts(subset=["Genre"])
# Out:
# Genre
# Action,Adventure,Sci-Fi      50
# Drama                        48
# Comedy,Drama,Romance         35
# Comedy                       32
# Drama,Romance                31
#                              ..
# Animation,Comedy,Drama        1
# Animation,Action,Comedy       1
# Adventure,Horror,Mystery      1
# Adventure,Fantasy,Mystery     1
# Thriller,War                  1
# Length: 207, dtype: int64

# %%
# 8. Who are the top 5 directors with the most movies in the dataset?
dir=data.value_counts(subset=["Director"])
print("Top 5 directors with the most movies in the dataset are\n\n",dir[0:5])
# Out:
# Top 5 directors with the most movies in the dataset are
#
#  Director
# Ridley Scott          8
# M. Night Shyamalan    6
# David Yates           6
# Michael Bay           6
# Paul W.S. Anderson    6
# dtype: int64

# %%
# 9. Create a line plot showing the number of movies released each year
x=data.value_counts(subset=['Year'])
y=data['Year'].unique()
fig=plt.figure()
plt.plot(x,y)
plt.show()

# %%
# 10. Draw a histogram depicting the distribution of movie runtimes.
data.hist(column='Runtime (Minutes)')
# Out:
# array([[<Axes: title={'center': 'Runtime (Minutes)'}>]], dtype=object)

# %%
# 11. Plot a histogram showcasing the distribution of movie ratings
data.hist(column='Rating')
# Out:
# array([[<Axes: title={'center': 'Rating'}>]], dtype=object)

# %%
# 12. Calculate the correlation coefficient between movie ratings and runtimes.
print("Correlation coefficient between movie ratings and runtimes are ",data['Rating'].corr(data['Runtime (Minutes)']))
# Out:
# Correlation coefficient between movie ratings and runtimes are  0.3922142455250512

# %%
# 13. Identify the 3 most frequent actors in the dataset.
data.value_counts(subset=['Actors']).nlargest(3)
# Out:
# Actors
# Daniel Radcliffe, Emma Watson, Rupert Grint, Michael Gambon            2
# Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Woody Harrelson    2
# Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese Gibson                   2
# dtype: int64

# %%
# 14. Is there any visible relationship between box office earnings and movie ratings?
data['Revenue (Millions)'].corr(data['Rating'])
# Out:
# 0.21765389419106002

# %%
# 15. List the languages in which movies are released. How would you display this information as a frequency count?

# %%
# 16. Plot a histogram of movie budgets to understand their distribution
data.hist(column='Revenue (Millions)')
# Out:
# array([[<Axes: title={'center': 'Revenue (Millions)'}>]], dtype=object)

# %%
# 17. Which production company has produced the highest number of movies?
production_company_counts = data["Genre"].value_counts()

# Get the production company with the highest number of movies
top_production_company = production_company_counts.idxmax()
highest_movie_count = production_company_counts.max()

# Display the result
print(f"The production company with the highest number of movies is '{top_production_company}' with {highest_movie_count} movies.")
# Out:
# The production company with the highest number of movies is 'Action,Adventure,Sci-Fi' with 50 movies.

# %%
# 18. Present the distribution of movies across different countries using a bar plot.

# %%
# 19. Create a word cloud visualization using movie titles or keywords from descriptions.

# %%
# 20. Plot the average movie ratings over the years to identify trends.
x=data['Year'].unique()
y=data.groupby(['Year'])['Rating'].mean()
plt.xlabel('years')
plt.ylabel('movie ratings')
plt.plot(x,y)

# %%
# 21. Identify trends in average ratings over the years. What insights can you gather?
x=data['Year'].unique()
y=data.groupby(['Year'])['Rating'].mean()
plt.xlabel('years')
plt.ylabel('movie ratings')
plt.scatter(x,y)

# %%
# 22. Discover the most common director-actor pairs. Who are they?
a=(data['Director']+ "--------------"+data['Actors']).mode()
print("The Most Frequent directors and actors are :\n    Directors--------------Actors\n",a)
# Out:
# The Most Frequent directors and actors are :
#     Directors--------------Actors
#  0    David Yates--------------Daniel Radcliffe, Emm...
# 1    Francis Lawrence--------------Jennifer Lawrenc...
# 2    Michael Bay--------------Shia LaBeouf, Megan F...
# dtype: object

# %%
# 23. Analyze how movie runtimes have changed over the years. Are movies getting longer or shorter?
x=data['Year'].unique()
y=data.groupby(['Year'])['Runtime (Minutes)'].count()
plt.xlabel('Years')
plt.ylabel('Runtimes (minutes)')
plt.scatter(x,y)

# %%
# 24. Plot the trends of different genres over the years. Which genres have become more popular?
y=data['Year'].unique()
x=data.groupby(['Year'])['Genre'].count()
plt.xlabel('years')
plt.ylabel('Genre')
plt.plot(x,y)
x2=data.value_counts(subset='Genre')
y
# Out:
# array([2014, 2012, 2016, 2015, 2007, 2011, 2008, 2006, 2009, 2010, 2013],
#       dtype=int64)

# %%
# 25. Extract and analyze popular keywords from movie descriptions. What themes emerge?

# %%
# 26. Create bar plots to compare metrics like rating, revenue, and budget. What comparisons can you make
data.plot.bar(y='Revenue (Millions)',x='Rating')
# Out:
# <Axes: xlabel='Rating'>

# %%
# 27. Investigate how movie budgets relate to their earnings. Is there a pattern?

# %%
# 28. Analyze the relationship between the number of votes and movie ratings.
data['Rating'].corr(data['Votes'])
# Out:
# 0.5115373197657554

# %%
# 29. Explore the distribution of ratings for different genres. Are there variations?
x=data['Genre'].unique()
x1=data.value_counts('Genre')
y1=data['Rating'].unique()
y2=data.value_counts('Rating')
plt.scatter(x,x1)
plt.scatter(y1,y2)

# %%
# 30. Identify any outliers in the movie runtime data. How would you handle them?
plt.boxplot(data['Runtime (Minutes)'])
print("The outliers in Runtime is present after 160 on y axis")
# Out:
# The outliers in Runtime is present after 160 on y axis
